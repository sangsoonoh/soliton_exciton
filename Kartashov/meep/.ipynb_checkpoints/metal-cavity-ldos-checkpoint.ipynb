# %%
import math

import matplotlib.pyplot as plt
import numpy as np

import meep as mp


def metal_cavity(w):
    resolution = 50
    sxy = 2
    dpml = 1
    sxy += 2 * dpml
    cell = mp.Vector3(sxy, sxy)

    pml_layers = [mp.PML(dpml)]
    a = 1
    t = 0.1
    geometry = [
        mp.Block(mp.Vector3(a + 2 * t, a + 2 * t, mp.inf), material=mp.metal),
        mp.Block(mp.Vector3(a, a, mp.inf), material=mp.air),
    ]

    geometry.append(
        mp.Block(
            center=mp.Vector3(a / 2), size=mp.Vector3(2 * t, w, mp.inf), material=mp.air
        )
    )

    fcen = math.sqrt(0.5) / a
    df = 0.2
    sources = [
        mp.Source(
            src=mp.GaussianSource(fcen, fwidth=df), component=mp.Ez, center=mp.Vector3()
        )
    ]

    symmetries = [mp.Mirror(mp.Y)]

    sim = mp.Simulation(
        cell_size=cell,
        geometry=geometry,
        boundary_layers=pml_layers,
        sources=sources,
        symmetries=symmetries,
        resolution=resolution,
    )

    h = mp.Harminv(mp.Ez, mp.Vector3(), fcen, df)
    sim.run(mp.after_sources(h), until_after_sources=500)

    m = h.modes[0]
    f = m.freq
    Q = m.Q
    Vmode = 0.25 * a * a
    ldos_1 = Q / Vmode / (2 * math.pi * f * math.pi * 0.5)

    sim.reset_meep()

    T = 2 * Q * (1 / f)
    sim.run(mp.dft_ldos(f, 0, 1), until_after_sources=T)
    ldos_2 = sim.ldos_data[0]

    return ldos_1, ldos_2


ws = np.arange(0.2, 0.5, 0.1)
ldos_1 = np.zeros(len(ws))
ldos_2 = np.zeros(len(ws))

for j in range(len(ws)):
    ldos_1[j], ldos_2[j] = metal_cavity(ws[j])
    print(f"ldos:, {ldos_1[j]}, {ldos_2[2]}")

plt.figure(dpi=150)
plt.semilogy(1 / ws, ldos_1, "bo-", label="2Q/(πωV)")
plt.semilogy(1 / ws, ldos_2, "rs-", label="LDOS")
plt.xlabel("a/w")
plt.ylabel("2Q/(πωW) or LDOS")
plt.show()
# Out:
# Using MPI version 3.1, 1 processes
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00292918 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0300175 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 238.43/550.0 = 43.4% done in 4.0s, 5.2s to go
# on time step 23873 (time=238.73), 0.000167595 s/step
# Meep progress: 474.92/550.0 = 86.3% done in 8.0s, 1.3s to go
# on time step 47532 (time=475.32), 0.00016907 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.6740278049365201, -4.18151034465044e-05, 8059.621397311963, 6.284217954163792, -3.8309426912638673-4.981493088591664i, 5.583854856639115e-12+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00128034 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0287108 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=23964.80392436041)
# Meep progress: 263.27/23964.80392436041 = 1.1% done in 4.0s, 360.1s to go
# on time step 26358 (time=263.58), 0.000151759 s/step
# Meep progress: 527.59/23964.80392436041 = 2.2% done in 8.0s, 355.4s to go
# on time step 52787 (time=527.87), 0.000151349 s/step
# Meep progress: 791.76/23964.80392436041 = 3.3% done in 12.0s, 351.2s to go
# on time step 79224 (time=792.24), 0.000151305 s/step
# Meep progress: 1056.01/23964.80392436041 = 4.4% done in 16.0s, 347.1s to go
# on time step 105657 (time=1056.57), 0.00015133 s/step
# Meep progress: 1320.31/23964.80392436041 = 5.5% done in 20.0s, 343.0s to go
# on time step 132095 (time=1320.95), 0.000151299 s/step
# Meep progress: 1584.73/23964.80392436041 = 6.6% done in 24.0s, 338.9s to go
# on time step 158536 (time=1585.36), 0.000151283 s/step
# Meep progress: 1848.93/23964.80392436041 = 7.7% done in 28.0s, 334.9s to go
# on time step 184976 (time=1849.76), 0.000151288 s/step
# Meep progress: 2113.38/23964.80392436041 = 8.8% done in 32.0s, 330.9s to go
# on time step 211429 (time=2114.29), 0.000151213 s/step
# Meep progress: 2378.16/23964.80392436041 = 9.9% done in 36.0s, 326.8s to go
# on time step 237916 (time=2379.16), 0.000151022 s/step
# Meep progress: 2642.2200000000003/23964.80392436041 = 11.0% done in 40.0s, 322.8s to go
# on time step 264328 (time=2643.28), 0.00015145 s/step
# Meep progress: 2905.9700000000003/23964.80392436041 = 12.1% done in 44.0s, 318.9s to go
# on time step 290712 (time=2907.12), 0.00015161 s/step
# Meep progress: 3170.91/23964.80392436041 = 13.2% done in 48.0s, 314.8s to go
# on time step 317213 (time=3172.13), 0.000150941 s/step
# Meep progress: 3435.52/23964.80392436041 = 14.3% done in 52.0s, 310.7s to go
# on time step 343680 (time=3436.8), 0.000151134 s/step
# Meep progress: 3700.27/23964.80392436041 = 15.4% done in 56.0s, 306.7s to go
# on time step 370155 (time=3701.55), 0.000151091 s/step
# Meep progress: 3964.2200000000003/23964.80392436041 = 16.5% done in 60.0s, 302.7s to go
# on time step 396572 (time=3965.72), 0.00015142 s/step
# Meep progress: 4228.81/23964.80392436041 = 17.6% done in 64.0s, 298.7s to go
# on time step 423035 (time=4230.35), 0.000151156 s/step
# Meep progress: 4493.64/23964.80392436041 = 18.8% done in 68.0s, 294.7s to go
# on time step 449527 (time=4495.27), 0.00015099 s/step
# Meep progress: 4757.81/23964.80392436041 = 19.9% done in 72.0s, 290.7s to go
# on time step 475950 (time=4759.5), 0.000151386 s/step
# Meep progress: 5022.1900000000005/23964.80392436041 = 21.0% done in 76.0s, 286.7s to go
# on time step 502396 (time=5023.96), 0.000151253 s/step
# Meep progress: 5286.29/23964.80392436041 = 22.1% done in 80.0s, 282.7s to go
# on time step 528815 (time=5288.15), 0.000151412 s/step
# Meep progress: 5551.01/23964.80392436041 = 23.2% done in 84.0s, 278.7s to go
# on time step 555296 (time=5552.96), 0.000151056 s/step
# Meep progress: 5815.47/23964.80392436041 = 24.3% done in 88.0s, 274.6s to go
# on time step 581745 (time=5817.45), 0.000151239 s/step
# Meep progress: 6080.24/23964.80392436041 = 25.4% done in 92.0s, 270.6s to go
# on time step 608230 (time=6082.3), 0.000151031 s/step
# Meep progress: 6344.77/23964.80392436041 = 26.5% done in 96.0s, 266.6s to go
# on time step 634691 (time=6346.91), 0.000151171 s/step
# Meep progress: 6608.83/23964.80392436041 = 27.6% done in 100.0s, 262.6s to go
# on time step 661101 (time=6611.01), 0.000151461 s/step
# Meep progress: 6873.25/23964.80392436041 = 28.7% done in 104.0s, 258.6s to go
# on time step 687557 (time=6875.57), 0.000151197 s/step
# Meep progress: 7137.49/23964.80392436041 = 29.8% done in 108.0s, 254.6s to go
# on time step 713987 (time=7139.87), 0.000151345 s/step
# Meep progress: 7402.05/23964.80392436041 = 30.9% done in 112.0s, 250.6s to go
# on time step 740446 (time=7404.46), 0.000151179 s/step
# Meep progress: 7666.42/23964.80392436041 = 32.0% done in 116.0s, 246.6s to go
# on time step 766882 (time=7668.82), 0.000151311 s/step
# Meep progress: 7930.09/23964.80392436041 = 33.1% done in 120.0s, 242.6s to go
# on time step 793269 (time=7932.69), 0.000151595 s/step
# Meep progress: 8194.76/23964.80392436041 = 34.2% done in 124.0s, 238.6s to go
# on time step 819740 (time=8197.4), 0.000151113 s/step
# Meep progress: 8459.35/23964.80392436041 = 35.3% done in 128.0s, 234.6s to go
# on time step 846209 (time=8462.09), 0.000151122 s/step
# Meep progress: 8724.19/23964.80392436041 = 36.4% done in 132.0s, 230.6s to go
# on time step 872702 (time=8727.02), 0.000150987 s/step
# Meep progress: 8989.0/23964.80392436041 = 37.5% done in 136.0s, 226.6s to go
# on time step 899188 (time=8991.88), 0.000151024 s/step
# Meep progress: 9252.98/23964.80392436041 = 38.6% done in 140.0s, 222.6s to go
# on time step 925593 (time=9255.93), 0.000151489 s/step
# Meep progress: 9517.86/23964.80392436041 = 39.7% done in 144.0s, 218.6s to go
# on time step 952089 (time=9520.89), 0.000150972 s/step
# Meep progress: 9782.15/23964.80392436041 = 40.8% done in 148.0s, 214.6s to go
# on time step 978523 (time=9785.23), 0.000151321 s/step
# Meep progress: 10045.83/23964.80392436041 = 41.9% done in 152.0s, 210.6s to go
# on time step 1004903 (time=10049), 0.000151634 s/step
# Meep progress: 10309.15/23964.80392436041 = 43.0% done in 156.0s, 206.6s to go
# on time step 1031242 (time=10312.4), 0.000151867 s/step
# Meep progress: 10573.130000000001/23964.80392436041 = 44.1% done in 160.0s, 202.7s to go
# on time step 1057647 (time=10576.5), 0.000151486 s/step
# Meep progress: 10837.61/23964.80392436041 = 45.2% done in 164.0s, 198.7s to go
# on time step 1084097 (time=10841), 0.000151232 s/step
# Meep progress: 11101.99/23964.80392436041 = 46.3% done in 168.0s, 194.6s to go
# on time step 1110545 (time=11105.5), 0.000151241 s/step
# Meep progress: 11366.67/23964.80392436041 = 47.4% done in 172.0s, 190.6s to go
# on time step 1137020 (time=11370.2), 0.000151089 s/step
# Meep progress: 11631.050000000001/23964.80392436041 = 48.5% done in 176.0s, 186.6s to go
# on time step 1163450 (time=11634.5), 0.000151346 s/step
# Meep progress: 11894.95/23964.80392436041 = 49.6% done in 180.0s, 182.7s to go
# on time step 1189861 (time=11898.6), 0.000151452 s/step
# Meep progress: 12159.68/23964.80392436041 = 50.7% done in 184.0s, 178.6s to go
# on time step 1216340 (time=12163.4), 0.000151063 s/step
# Meep progress: 12423.76/23964.80392436041 = 51.8% done in 188.0s, 174.6s to go
# on time step 1242751 (time=12427.5), 0.000151457 s/step
# Meep progress: 12688.04/23964.80392436041 = 52.9% done in 192.0s, 170.6s to go
# on time step 1269187 (time=12691.9), 0.00015131 s/step
# Meep progress: 12952.64/23964.80392436041 = 54.0% done in 196.0s, 166.6s to go
# on time step 1295655 (time=12956.6), 0.000151126 s/step
# Meep progress: 13216.73/23964.80392436041 = 55.2% done in 200.0s, 162.6s to go
# on time step 1322072 (time=13220.7), 0.000151421 s/step
# Meep progress: 13481.4/23964.80392436041 = 56.3% done in 204.0s, 158.6s to go
# on time step 1348544 (time=13485.4), 0.000151104 s/step
# Meep progress: 13744.93/23964.80392436041 = 57.4% done in 208.0s, 154.7s to go
# on time step 1374898 (time=13749), 0.000151785 s/step
# Meep progress: 14009.18/23964.80392436041 = 58.5% done in 212.0s, 150.7s to go
# on time step 1401336 (time=14013.4), 0.000151298 s/step
# Meep progress: 14271.67/23964.80392436041 = 59.6% done in 216.0s, 146.7s to go
# on time step 1427595 (time=14276), 0.000152334 s/step
# Meep progress: 14534.53/23964.80392436041 = 60.6% done in 220.0s, 142.7s to go
# on time step 1453874 (time=14538.7), 0.000152216 s/step
# Meep progress: 14798.66/23964.80392436041 = 61.8% done in 224.0s, 138.7s to go
# on time step 1480305 (time=14803.1), 0.00015134 s/step
# Meep progress: 15063.130000000001/23964.80392436041 = 62.9% done in 228.0s, 134.7s to go
# on time step 1506754 (time=15067.5), 0.00015124 s/step
# Meep progress: 15327.33/23964.80392436041 = 64.0% done in 232.0s, 130.7s to go
# on time step 1533187 (time=15331.9), 0.000151332 s/step
# Meep progress: 15591.61/23964.80392436041 = 65.1% done in 236.0s, 126.7s to go
# on time step 1559613 (time=15596.1), 0.000151366 s/step
# Meep progress: 15855.41/23964.80392436041 = 66.2% done in 240.0s, 122.8s to go
# on time step 1586017 (time=15860.2), 0.000151492 s/step
# Meep progress: 16120.01/23964.80392436041 = 67.3% done in 244.0s, 118.7s to go
# on time step 1612480 (time=16124.8), 0.000151156 s/step
# Meep progress: 16384.25/23964.80392436041 = 68.4% done in 248.0s, 114.7s to go
# on time step 1638906 (time=16389.1), 0.00015137 s/step
# Meep progress: 16648.83/23964.80392436041 = 69.5% done in 252.0s, 110.7s to go
# on time step 1665374 (time=16653.7), 0.000151127 s/step
# Meep progress: 16913.28/23964.80392436041 = 70.6% done in 256.0s, 106.7s to go
# on time step 1691825 (time=16918.2), 0.000151224 s/step
# Meep progress: 17177.12/23964.80392436041 = 71.7% done in 260.0s, 102.7s to go
# on time step 1718217 (time=17182.2), 0.000151566 s/step
# Meep progress: 17441.82/23964.80392436041 = 72.8% done in 264.0s, 98.7s to go
# on time step 1744695 (time=17447), 0.000151073 s/step
# Meep progress: 17706.54/23964.80392436041 = 73.9% done in 268.0s, 94.7s to go
# on time step 1771167 (time=17711.7), 0.000151105 s/step
# Meep progress: 17970.510000000002/23964.80392436041 = 75.0% done in 272.0s, 90.7s to go
# on time step 1797571 (time=17975.7), 0.000151498 s/step
# Meep progress: 18235.18/23964.80392436041 = 76.1% done in 276.0s, 86.7s to go
# on time step 1824042 (time=18240.4), 0.000151113 s/step
# Meep progress: 18499.260000000002/23964.80392436041 = 77.2% done in 280.0s, 82.7s to go
# on time step 1850456 (time=18504.6), 0.000151439 s/step
# Meep progress: 18763.69/23964.80392436041 = 78.3% done in 284.0s, 78.7s to go
# on time step 1876905 (time=18769), 0.000151235 s/step
# Meep progress: 19028.34/23964.80392436041 = 79.4% done in 288.0s, 74.7s to go
# on time step 1903380 (time=19033.8), 0.00015109 s/step
# Meep progress: 19292.91/23964.80392436041 = 80.5% done in 292.0s, 70.7s to go
# on time step 1929837 (time=19298.4), 0.00015119 s/step
# Meep progress: 19557.2/23964.80392436041 = 81.6% done in 296.0s, 66.7s to go
# on time step 1956253 (time=19562.5), 0.000151427 s/step
# Meep progress: 19821.260000000002/23964.80392436041 = 82.7% done in 300.0s, 62.7s to go
# on time step 1982678 (time=19826.8), 0.000151376 s/step
# Meep progress: 20085.84/23964.80392436041 = 83.8% done in 304.0s, 58.7s to go
# on time step 2009148 (time=20091.5), 0.000151115 s/step
# Meep progress: 20347.850000000002/23964.80392436041 = 84.9% done in 308.0s, 54.8s to go
# on time step 2035352 (time=20353.5), 0.000152654 s/step
# Meep progress: 20612.75/23964.80392436041 = 86.0% done in 312.0s, 50.7s to go
# on time step 2061851 (time=20618.5), 0.00015095 s/step
# Meep progress: 20877.81/23964.80392436041 = 87.1% done in 316.0s, 46.7s to go
# on time step 2088352 (time=20883.5), 0.000150938 s/step
# Meep progress: 21143.09/23964.80392436041 = 88.2% done in 320.0s, 42.7s to go
# on time step 2114892 (time=21148.9), 0.000150721 s/step
# Meep progress: 21408.45/23964.80392436041 = 89.3% done in 324.0s, 38.7s to go
# on time step 2141433 (time=21414.3), 0.000150714 s/step
# Meep progress: 21673.08/23964.80392436041 = 90.4% done in 328.0s, 34.7s to go
# on time step 2167891 (time=21678.9), 0.000151188 s/step
# Meep progress: 21937.84/23964.80392436041 = 91.5% done in 332.0s, 30.7s to go
# on time step 2194382 (time=21943.8), 0.000150997 s/step
# Meep progress: 22203.05/23964.80392436041 = 92.6% done in 336.0s, 26.7s to go
# on time step 2220910 (time=22209.1), 0.000150786 s/step
# Meep progress: 22468.2/23964.80392436041 = 93.8% done in 340.0s, 22.6s to go
# on time step 2247426 (time=22474.3), 0.000150853 s/step
# Meep progress: 22732.99/23964.80392436041 = 94.9% done in 344.0s, 18.6s to go
# on time step 2273908 (time=22739.1), 0.00015105 s/step
# Meep progress: 22997.93/23964.80392436041 = 96.0% done in 348.0s, 14.6s to go
# on time step 2300398 (time=23004), 0.000151002 s/step
# Meep progress: 23261.510000000002/23964.80392436041 = 97.1% done in 352.0s, 10.6s to go
# on time step 2326765 (time=23267.7), 0.000151708 s/step
# Meep progress: 23526.27/23964.80392436041 = 98.2% done in 356.0s, 6.6s to go
# on time step 2353240 (time=23532.4), 0.000151087 s/step
# Meep progress: 23790.46/23964.80392436041 = 99.3% done in 360.0s, 2.6s to go
# on time step 2379673 (time=23796.7), 0.000151328 s/step
# ldos1:, 0.6740278049365201, 4395.243600122831
# run 1 finished at t = 23964.81 (2396481 timesteps)
# ldos:, 4846.152480381243, 0.0
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.001198 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0283094 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 239.97/550.0 = 43.6% done in 4.0s, 5.2s to go
# on time step 24026 (time=240.26), 0.000166489 s/step
# Meep progress: 475.53000000000003/550.0 = 86.5% done in 8.0s, 1.3s to go
# on time step 47588 (time=475.88), 0.000169769 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.6687513677299789, -0.0002630405269102228, 1271.194548584195, 4.90532493086038, 0.795154578784707+4.840448519833478i, 1.1257810788099364e-11+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00122939 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.3,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0279032 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=3851.6955476267945)
# Meep progress: 262.3/3851.6955476267945 = 6.8% done in 4.0s, 54.7s to go
# on time step 26259 (time=262.59), 0.000152334 s/step
# Meep progress: 524.73/3851.6955476267945 = 13.6% done in 8.0s, 50.7s to go
# on time step 52510 (time=525.1), 0.000152378 s/step
# Meep progress: 788.61/3851.6955476267945 = 20.5% done in 12.0s, 46.6s to go
# on time step 78904 (time=789.04), 0.000151552 s/step
# Meep progress: 1051.58/3851.6955476267945 = 27.3% done in 16.0s, 42.6s to go
# on time step 105206 (time=1052.06), 0.000152082 s/step
# Meep progress: 1314.54/3851.6955476267945 = 34.1% done in 20.0s, 38.6s to go
# on time step 131510 (time=1315.1), 0.000152072 s/step
# Meep progress: 1577.93/3851.6955476267945 = 41.0% done in 24.0s, 34.6s to go
# on time step 157860 (time=1578.6), 0.000151811 s/step
# Meep progress: 1840.66/3851.6955476267945 = 47.8% done in 28.0s, 30.6s to go
# on time step 184138 (time=1841.38), 0.00015222 s/step
# Meep progress: 2104.56/3851.6955476267945 = 54.6% done in 32.0s, 26.6s to go
# on time step 210537 (time=2105.37), 0.000151521 s/step
# Meep progress: 2367.93/3851.6955476267945 = 61.5% done in 36.0s, 22.6s to go
# on time step 236882 (time=2368.82), 0.000151833 s/step
# Meep progress: 2631.21/3851.6955476267945 = 68.3% done in 40.0s, 18.6s to go
# on time step 263215 (time=2632.15), 0.000151905 s/step
# Meep progress: 2894.4500000000003/3851.6955476267945 = 75.1% done in 44.0s, 14.6s to go
# on time step 289539 (time=2895.39), 0.000151955 s/step
# Meep progress: 3157.36/3851.6955476267945 = 82.0% done in 48.0s, 10.6s to go
# on time step 315851 (time=3158.51), 0.000152025 s/step
# Meep progress: 3420.71/3851.6955476267945 = 88.8% done in 52.0s, 6.6s to go
# on time step 342191 (time=3421.91), 0.000151862 s/step
# Meep progress: 3684.76/3851.6955476267945 = 95.7% done in 56.0s, 2.5s to go
# on time step 368605 (time=3686.05), 0.000151435 s/step
# ldos1:, 0.6687513677299789, 685.5049361497383
# run 1 finished at t = 3851.7000000000003 (385170 timesteps)
# ldos:, 770.3845854667046, 0.0
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00124524 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0288096 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=550.0)
# Meep progress: 238.38/550.0 = 43.3% done in 4.0s, 5.2s to go
# on time step 23868 (time=238.68), 0.000167598 s/step
# Meep progress: 474.43/550.0 = 86.3% done in 8.0s, 1.3s to go
# on time step 47479 (time=474.79), 0.000169414 s/step
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# harminv0:, 0.656920908216682, -0.001741264542262277, 188.6332869798177, 2.1681042061243714, 2.0296049848243456-0.7624824287748265i, 1.442617221910979e-10+0.0i
# run 0 finished at t = 550.0 (55000 timesteps)
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00121835 s
# Working in 2D dimensions.
# Computational cell is 4 x 4 x 0 with resolution 50
#      block, center = (0,0,0)
#           size (1.2,1.2,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (-1e+20,-1e+20,-1e+20)
#      block, center = (0,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0.5,0,0)
#           size (0.2,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0298316 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=624.2952754902968)
# Meep progress: 261.11/624.2952754902968 = 41.8% done in 4.0s, 5.6s to go
# on time step 26138 (time=261.38), 0.000153034 s/step
# Meep progress: 524.09/624.2952754902968 = 83.9% done in 8.0s, 1.5s to go
# on time step 52442 (time=524.42), 0.000152069 s/step
# ldos1:, 0.656920908216682, 98.45046179106856
# run 1 finished at t = 624.3000000000001 (62430 timesteps)
# ldos:, 116.37655414575866, 98.45046179106856
